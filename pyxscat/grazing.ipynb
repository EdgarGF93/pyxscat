# %%
# %matplotlib widget
from grazing import GIGrid

# %%
gi = GIGrid()
gi.draw_unit_vectors()
gi.draw_incoming_beam()
gi.draw_outcoming_beam()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# $$ \vec{k}_{i,lab} = \begin{pmatrix} k_{i,lab,x} \\ k_{i,lab,y} \\ k_{i,lab,z} \end{pmatrix} = \begin{pmatrix} k_{0} \\ 0 \\ 0 \end{pmatrix} $$
